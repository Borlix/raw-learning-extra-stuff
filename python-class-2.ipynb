# %%
city = "Kathmandu"
print(f"I live in {city}")

# %%
devide = 5//2
print(devide)

# %%
a = 10
b = 3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)

# %%
print(10>5)
print(10==5)

# %%
age = 20
print( age <= 18 and age >= 65)
print( age >= 18 or age <= 65)

# %%
print (not True)

# %%
temperature = 20
if temperature > 30:
    print("Its Hot outside\nStay hydrated!")
else:
    print("Its cold outside\nUse warm cloths")

# %%
score = 95

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")

# %%
score = 95

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

print(f"Your grade : {grade}")

# %%
has_ticket = False
age = 18
if has_ticket :
    if age >=18:
        print("Welcome to the movie show")
    elif age >=13:
        print("Welcome to PG-13 show")
    else :
        print("Sorry, You are too young!")
else:
    print("Sorry, Buy ticket first!")

# %% [markdown]
# Q1. WAP to find years of experiance of a developer to range it.

# %%
years_experience = 8
if years_experience <= 0:
    print("Error!")
elif years_experience <= 2:
    print("Juniour")
elif years_experience < 6:
    print("Mid-lvl")
elif years_experience > 6:
    print("Senior")
# Out:
# Senior
